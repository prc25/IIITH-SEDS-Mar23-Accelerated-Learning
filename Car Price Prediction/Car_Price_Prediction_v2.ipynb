# %% [markdown]
# <a href="https://colab.research.google.com/github/prc25/IIITH-SEDS-Mar23-Accelerated-Learning/blob/main/Car%20Price%20Prediction/Car_Price_Prediction_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Domain:
# Automobiles, Sales and Marketing
#
# ##Business Context:
# There is a huge demand for refurbished cars in the Indian Market today. As sales of new cars have slowed down in the recent past, the refurbished car market has continued to grow over the past year and is larger than the new car market now.
#
# Consider this: In 2018-19, the sales of refurbished cars which were previously owned by someone has increased steadily, and it is currently estimated to be approximately 1.3 times the sales of new cars. There are multiple reasons for this shift. However, the key reason is the increase in total cost of ownership of new cars which includes taxes, insurances.
#
# There is a slowdown in new car sales and that could mean that the demand is shifting towards the pre-owned market.

# %%
# Importing Train data set
import pandas as pd

github_path='https://raw.githubusercontent.com/prc25/IIITH-SEDS-Mar23-Accelerated-Learning/main/Car%20Price%20Prediction/Training_Data_Set.csv'

tdf= pd.read_csv(github_path,index_col=0)

# printing first 5 records of the tdf dataframe
tdf.head()
# Out:
#         Maker    model   Location  Distance       Owner Type  \
# Id
# 25001   skoda  octavia  Ahmedabad        NaN          Second
# 25002    fiat    panda  Ahmedabad    27750.0           Third
# 25003     bmw       x1  Hyderabad    46000.0           Third
# 25004  nissan     juke     Mumbai    43949.0           Third
# 25005     bmw       x5     Jaipur    59524.0  Fourth & Above
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# Id
# 25001              1964          55                 1964         147.0
# 25002              2012           7                 1242          51.0
# 25003              2014           5                 1995         105.0
# 25004              2011           8                 1618         140.0
# 25005              2012           7                 2993         180.0
#
#       body_type  Vroom Audit Rating transmission door_count seat_count  \
# Id
# 25001   compact                   8          man       None       None
# ...

# %%
# Checking basic information about the tdf to understand the to number of records and columns and non null values
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53515 entries, 25001 to 78515
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Maker                53515 non-null  object
#  1   model                53515 non-null  object
#  2   Location             53515 non-null  object
#  3   Distance             52304 non-null  float64
#  4   Owner Type           53515 non-null  object
#  5   manufacture_year     53515 non-null  int64
#  6   Age of car           53515 non-null  int64
#  7   engine_displacement  53515 non-null  int64
#  8   engine_power         52076 non-null  float64
#  9   body_type            4136 non-null   object
#  10  Vroom Audit Rating   53515 non-null  int64
#  11  transmission         53515 non-null  object
#  12  door_count           53515 non-null  object
#  13  seat_count           53515 non-null  object
#  14  fuel_type            53515 non-null  object
# ...

# %%
# checking basic descriptive stats on tdf file
tdf.describe(include='all')
# Out:
#         Maker    model    Location     Distance  Owner Type  manufacture_year  \
# count   53515    53515       53515  5.230400e+04      53515      53515.000000
# unique      8       23          11           NaN          4               NaN
# top     skoda  octavia  Coimbatore           NaN      First               NaN
# freq    21563    12619        4976           NaN      13406               NaN
# mean      NaN      NaN         NaN  9.454626e+04        NaN       2010.408110
# std       NaN      NaN         NaN  2.755617e+05        NaN          4.650322
# min       NaN      NaN         NaN  0.000000e+00        NaN       1934.000000
# 25%       NaN      NaN         NaN  1.549000e+04        NaN       2008.000000
# 50%       NaN      NaN         NaN  6.552000e+04        NaN       2011.000000
# 75%       NaN      NaN         NaN  1.356410e+05        NaN       2014.000000
# max       NaN      NaN         NaN  9.899800e+06        NaN       2016.000000
#
# ...

# %%
#Finding null values count of each column in tdf frame
tdf.isnull().sum()
# Out:
# Maker                      0
# model                      0
# Location                   0
# Distance                1211
# Owner Type                 0
# manufacture_year           0
# Age of car                 0
# engine_displacement        0
# engine_power            1439
# body_type              49379
# Vroom Audit Rating         0
# transmission               0
# door_count                 0
# seat_count                 0
# fuel_type                  0
# Price                      0
# dtype: int64

# %%
tdf.head()
# Out:
#         Maker    model   Location  Distance       Owner Type  \
# Id
# 25001   skoda  octavia  Ahmedabad        NaN          Second
# 25002    fiat    panda  Ahmedabad    27750.0           Third
# 25003     bmw       x1  Hyderabad    46000.0           Third
# 25004  nissan     juke     Mumbai    43949.0           Third
# 25005     bmw       x5     Jaipur    59524.0  Fourth & Above
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# Id
# 25001              1964          55                 1964         147.0
# 25002              2012           7                 1242          51.0
# 25003              2014           5                 1995         105.0
# 25004              2011           8                 1618         140.0
# 25005              2012           7                 2993         180.0
#
#       body_type  Vroom Audit Rating transmission door_count seat_count  \
# Id
# 25001   compact                   8          man       None       None
# ...

# %%
tdf=tdf.dropna(subset=['Distance ','engine_power'])

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51119 entries, 25002 to 78515
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Maker                51119 non-null  object
#  1   model                51119 non-null  object
#  2   Location             51119 non-null  object
#  3   Distance             51119 non-null  float64
#  4   Owner Type           51119 non-null  object
#  5   manufacture_year     51119 non-null  int64
#  6   Age of car           51119 non-null  int64
#  7   engine_displacement  51119 non-null  int64
#  8   engine_power         51119 non-null  float64
#  9   body_type            2689 non-null   object
#  10  Vroom Audit Rating   51119 non-null  int64
#  11  transmission         51119 non-null  object
#  12  door_count           51119 non-null  object
#  13  seat_count           51119 non-null  object
#  14  fuel_type            51119 non-null  object
# ...

# %%
tdf=tdf.drop(['body_type'],axis=1)

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51119 entries, 25002 to 78515
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Maker                51119 non-null  object
#  1   model                51119 non-null  object
#  2   Location             51119 non-null  object
#  3   Distance             51119 non-null  float64
#  4   Owner Type           51119 non-null  object
#  5   manufacture_year     51119 non-null  int64
#  6   Age of car           51119 non-null  int64
#  7   engine_displacement  51119 non-null  int64
#  8   engine_power         51119 non-null  float64
#  9   Vroom Audit Rating   51119 non-null  int64
#  10  transmission         51119 non-null  object
#  11  door_count           51119 non-null  object
#  12  seat_count           51119 non-null  object
#  13  fuel_type            51119 non-null  object
#  14  Price                51119 non-null  float64
# ...

# %%
tdf.head()
# Out:
#         Maker    model   Location  Distance       Owner Type  \
# Id
# 25002    fiat    panda  Ahmedabad    27750.0           Third
# 25003     bmw       x1  Hyderabad    46000.0           Third
# 25004  nissan     juke     Mumbai    43949.0           Third
# 25005     bmw       x5     Jaipur    59524.0  Fourth & Above
# 25006   skoda  octavia    Chennai    12015.0           First
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# Id
# 25002              2012           7                 1242          51.0
# 25003              2014           5                 1995         105.0
# 25004              2011           8                 1618         140.0
# 25005              2012           7                 2993         180.0
# 25006              2015           4                 1968         110.0
#
#        Vroom Audit Rating transmission door_count seat_count fuel_type  \
# Id
# 25002                   6          man          4          4    petrol
# ...

# %%
utdf=tdf['Maker'].value_counts()

# %%
utdf
# Out:
# skoda       20102
# toyota       7720
# audi         7251
# bmw          6964
# nissan       5147
# hyundai      2073
# fiat         1824
# maserati       38
# Name: Maker, dtype: int64

# %%
tdf['fuel_type'].value_counts()
# Out:
# diesel    26597
# petrol    24522
# Name: fuel_type, dtype: int64

# %%
tdf['seat_count'].value_counts()
# Out:
# 5       37927
# None     7023
# 4        4460
# 7         850
# 2         724
# 3         109
# 6          22
# 9           2
# 1           1
# 8           1
# Name: seat_count, dtype: int64

# %%
tdf['transmission'].value_counts()
# Out:
# man     35283
# auto    15836
# Name: transmission, dtype: int64

# %%
tdf['Age of car'].value_counts()
# Out:
# 4     11633
# 7      6189
# 8      4825
# 5      4812
# 9      3655
# 6      2856
# 10     2817
# 11     2731
# 12     2670
# 13     1901
# 14     1541
# 15     1265
# 16      877
# 18      688
# 17      676
# 19      647
# 20      498
# 21      265
# 3       139
# 22      134
# 23       71
# 25       34
# 28       32
# 24       30
# 26       21
# 27       20
# 29       17
# 30       11
# 31       10
# 35        5
# 34        5
# 51        5
# 46        4
# 37        4
# 39        4
# 33        3
# 48        3
# 36        3
# 47        2
# 57        2
# 53        2
# 32        2
# 43        1
# 38        1
# 45        1
# 60        1
# 59        1
# 50        1
# 67        1
# 63        1
# 85        1
# 56        1
# Name: Age of car, dtype: int64

# %%
tdf.describe(include='all')
# Out:
#         Maker    model    Location     Distance  Owner Type  manufacture_year  \
# count   51119    51119       51119  5.111900e+04      51119      51119.000000
# unique      8       23          11           NaN          4               NaN
# top     skoda  octavia  Coimbatore           NaN      First               NaN
# freq    20102    11606        4772           NaN      12819               NaN
# mean      NaN      NaN         NaN  9.295331e+04        NaN       2010.473796
# std       NaN      NaN         NaN  2.441553e+05        NaN          4.509153
# min       NaN      NaN         NaN  0.000000e+00        NaN       1934.000000
# 25%       NaN      NaN         NaN  1.720000e+04        NaN       2008.000000
# 50%       NaN      NaN         NaN  6.700000e+04        NaN       2012.000000
# 75%       NaN      NaN         NaN  1.361620e+05        NaN       2014.000000
# max       NaN      NaN         NaN  9.899800e+06        NaN       2016.000000
#
# ...

# %%
github_path_test='https://raw.githubusercontent.com/prc25/IIITH-SEDS-Mar23-Accelerated-Learning/main/Car%20Price%20Prediction/Test_Data_Set.csv'


dft= pd.read_csv(github_path_test,index_col=0)

# printing first 5 records of the tdf dataframe
dft.head()
# Out:
#        Maker    model    Location  Distance       Owner Type  \
# Id
# 11001  skoda  octavia      Mumbai   150000.0           First
# 11002  skoda    rapid  Coimbatore    29376.0           Third
# 11003  skoda  octavia  Coimbatore    30563.0          Second
# 11004   audi       q3       Delhi     8650.0  Fourth & Above
# 11005   audi       tt     Chennai     6400.0           Third
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# Id
# 11001              2007          12                 1595          75.0
# 11002              2014           5                 1598          77.0
# 11003              2014           5                 1968         110.0
# 11004              2015           4                 1968         110.0
# 11005              2015           4                 1984         169.0
#
#       body_type  Vroom Audit Rating transmission door_count seat_count  \
# Id
# 11001       NaN                   5          man          4          5
# ...

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5615 entries, 11001 to 16615
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Maker                5615 non-null   object
#  1   model                5615 non-null   object
#  2   Location             5615 non-null   object
#  3   Distance             5487 non-null   float64
#  4   Owner Type           5615 non-null   object
#  5   manufacture_year     5615 non-null   int64
#  6   Age of car           5615 non-null   int64
#  7   engine_displacement  5615 non-null   int64
#  8   engine_power         5447 non-null   float64
#  9   body_type            422 non-null    object
#  10  Vroom Audit Rating   5615 non-null   int64
#  11  transmission         5615 non-null   object
#  12  door_count           5615 non-null   object
#  13  seat_count           5615 non-null   object
#  14  fuel_type            5615 non-null   object
# ...

# %%
dft=dft.dropna(subset=['Distance ','engine_power'])
dft=dft.drop(['body_type'],axis=1)

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5348 entries, 11001 to 16615
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Maker                5348 non-null   object
#  1   model                5348 non-null   object
#  2   Location             5348 non-null   object
#  3   Distance             5348 non-null   float64
#  4   Owner Type           5348 non-null   object
#  5   manufacture_year     5348 non-null   int64
#  6   Age of car           5348 non-null   int64
#  7   engine_displacement  5348 non-null   int64
#  8   engine_power         5348 non-null   float64
#  9   Vroom Audit Rating   5348 non-null   int64
#  10  transmission         5348 non-null   object
#  11  door_count           5348 non-null   object
#  12  seat_count           5348 non-null   object
#  13  fuel_type            5348 non-null   object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 626.7+ KB

# %%
location_me = tdf.groupby("Location")["Price"].mean()
transmission_me = tdf.groupby("transmission")["Price"].mean()
fuel_type_me = tdf.groupby("fuel_type")["Price"].mean()
owner_type_me = tdf.groupby("Owner Type")["Price"].mean()
manufacturer_me = tdf.groupby("model")["Price"].mean()
brands_me = tdf.groupby("Maker")["Price"].mean()
manufacture_year_me=tdf.groupby('manufacture_year')["Price"].mean()
Age_of_car_me=tdf.groupby('Age of car')["Price"].mean()
Vroom_Audit_Rating_me=tdf.groupby('Vroom Audit Rating')["Price"].mean()
door_count_me	=tdf.groupby('door_count')["Price"].mean()
seat_count_me = tdf.groupby('seat_count')["Price"].mean()



def mean_encoding(dataset) :

    op_set_5 = (dataset
                .assign( Location = dataset.Location.replace(location_me.index, location_me.values) )
                .assign( Transmission = dataset.Transmission.replace(transmission_me.index, transmission_me.values) )
                .assign( Fuel_Type = dataset.Fuel_Type.replace(fuel_type_me.index, fuel_type_me.values) )
                .assign( Owner_Type = dataset.Owner_Type.replace(owner_type_me.index, owner_type_me.values) )
                .assign( Manufacturer = dataset.Manufacturer.replace(manufacturer_me.index, manufacturer_me.values) )
                .assign( Brands = dataset.Brands.replace(brands_me.index, brands_me.values) )
                .assign( manufacture_year = dataset.manufacture_year.replace(manufacture_year_me.index,manufacture_year_me.values))
                .assign()
               )

    return op_set_5

train_data = mean_encoding(train_data)
train_data.head()
